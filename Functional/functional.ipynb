# %%
# map, filter, zip, and reduce
# map(action, data)

# %%
# def multiply_by2(li):
#     new_list = []
#     for item in li:
#         new_list.append(item*2)
    
#     return new_list
my_list = (1,2,3,4)
def multiply_by2(item):
    return item*2

# %%
map(multiply_by2, [1,2,3])

# %%
list(map(multiply_by2, my_list))
# Out:
# [2, 4, 6, 8]

# %%
def only_odd(item):
    return item%2 != 0

# %%
list(filter(only_odd, my_list))
# Out:
# [1, 3]

# %%
lst1 = [10,20,30,40]
lst2 = [5,15,25,35]
lst3 = [1,2,3,4]

# %%
list(zip(lst1,lst2,lst3))
# Out:
# [(10, 5, 1), (20, 15, 2), (30, 25, 3), (40, 35, 4)]

# %%
from functools import reduce

def accumulator(acc, item):
    print(acc, item)
    return acc+item

# %%
reduce(accumulator,lst1,0)
# Out:
# 0 10
# 10 20
# 30 30
# 60 40
# 100
