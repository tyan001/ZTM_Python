# %%
# lambda param: action(param)
from functools import reduce

# %%
lst1 = [10,15,20,25]

# %%
list(map(lambda item: item*2, lst1))
# Out:
# [20, 30, 40, 50]

# %%
list(filter(lambda item: item%2, lst1))
# Out:
# [15, 25]

# %%
reduce(lambda acc, item:item+acc, lst1, 1)
# Out:
# 71
